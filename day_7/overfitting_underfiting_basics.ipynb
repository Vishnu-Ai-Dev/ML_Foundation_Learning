# %%
train_score=0.98
test_score=0.45
if train_score>0.9 and test_score<0.7:
    print("overfitting😏")
elif train_score<0.7 and test_score<0.7:
    print("underfitting🙂‍↕️")
else:
    print("good fit! great job😘")
# Out:
# overfitting😏

# %%
#o
