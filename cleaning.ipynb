# %%
import pandas as pd
import numpy as np

#now we are creating datasets with missing values

data={"Age": [25,30,np.nan,22,28],
"salary":[30000,np.nan,25000,22000,28000]
     }
df=pd.DataFrame(data)
print("Original data:\n")
print(df)
#now we are filling the value with mean

df["Age"]=df["Age"].fillna(df["Age"].mean())
df["salary"]=df["salary"].fillna(df["salary"].mean())

print("\nCleaned data:\n")
print(df)
# Out:
# Original data:
#
#     Age   salary
# 0  25.0  30000.0
# 1  30.0      NaN
# 2   NaN  25000.0
# 3  22.0  22000.0
# 4  28.0  28000.0
#
# Cleaned data:
#
#      Age   salary
# 0  25.00  30000.0
# 1  30.00  26250.0
# 2  26.25  25000.0
# 3  22.00  22000.0
# 4  28.00  28000.0
