# %%
import pandas as pd
data={"hours":[1,2,3,4,5],
      "sleep":[6,7,6,5,8],
      "Marks":[30,40,50,60,70]
     }
df=pd.DataFrame(data)
print(df)
# Out:
#    hours  sleep  Marks
# 0      1      6     30
# 1      2      7     40
# 2      3      6     50
# 3      4      5     60
# 4      5      8     70

# %%
import pandas as pd
data={"hours":[1,2,3,4,5],
      "sleep":[6,7,6,5,8],
      "Marks":[30,40,50,60,70]
     }
df=pd.DataFrame(data)
x=df[["hours","sleep"]]
y=df["Marks"]
print(x)#features
print(y)#target
# Out:
#    hours  sleep
# 0      1      6
# 1      2      7
# 2      3      6
# 3      4      5
# 4      5      8
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: Marks, dtype: int64
