# %%
import pandas as pd
data={"Study hours":[2,4,None,5,10],
      "Sleep_hours":[6,7,5,None,8],
      "mobile_usage":[3,5,2,8,None],
      "Marks":[40,60,70,50,200]}
df=pd.DataFrame(data)
df.to_csv("student_data.csv",index=False)

# %%
import pandas as pd 
df=pd.read_csv("student_data.csv")
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    Study hours  Sleep_hours  mobile_usage  Marks
# 0          2.0          6.0           3.0     40
# 1          4.0          7.0           5.0     60
# 2          NaN          5.0           2.0     70
# 3          5.0          NaN           8.0     50
# 4         10.0          8.0           NaN    200
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Study hours   4 non-null      float64
#  1   Sleep_hours   4 non-null      float64
#  2   mobile_usage  4 non-null      float64
#  3   Marks         5 non-null      int64
# dtypes: float64(3), int64(1)
# memory usage: 288.0 bytes
# None
#        Study hours  Sleep_hours  mobile_usage       Marks
# count      4.00000     4.000000      4.000000    5.000000
# mean       5.25000     6.500000      4.500000   84.000000
# std        3.40343     1.290994      2.645751   65.802736
# min        2.00000     5.000000      2.000000   40.000000
# 25%        3.50000     5.750000      2.750000   50.000000
# 50%        4.50000     6.500000      4.000000   60.000000
# 75%        6.25000     7.250000      5.750000   70.000000
# max       10.00000     8.000000      8.000000  200.000000

# %%
import pandas as pd 
df=pd.read_csv("student_data.csv")
print(df.isnull().sum())
# Out:
# Study hours     1
# Sleep_hours     1
# mobile_usage    1
# Marks           0
# dtype: int64

# %%
import pandas as pd 
df=pd.read_csv("student_data.csv")
df=df.fillna(df.mean())
df=df[df["Marks"]<100]
